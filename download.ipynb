# %%
import os
import requests
import json
import shutil

os.chdir('imaterialist-challenge-furniture-2018/')

train_data = json.load(open('train.json'))

images_arr = train_data['images']
annotations_arr = train_data['annotations']
os.makedirs('train_data')

# %%
for img in images_arr:
    if img['image_id'] % 1000 == 0:
        print("Finished {} out of 194,828".format(img['image_id']))
    try:
        r = requests.get(img['url'][0],timeout=10)
        folder_path = 'train_data/'
        with open(folder_path+str(img['image_id'])+'.jpg','wb') as f:
            f.write(r.content)
        f.close()

    except Exception as e:
        print(e)
# Out:
# HTTPConnectionPool(host='pic.taocz.com', port=80): Max retries exceeded with url: /imgupload/baihuo/jiaju/20111115/303723.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3728470>, 'Connection to pic.taocz.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.liyangtuopan.com', port=80): Read timed out. (read timeout=10)
# HTTPConnectionPool(host='www.cnjdz.net', port=80): Read timed out. (read timeout=10)
# HTTPConnectionPool(host='www.t-nan.com', port=80): Read timed out. (read timeout=10)
# HTTPConnectionPool(host='spic1.51fanli.net', port=80): Read timed out. (read timeout=10)
# HTTPConnectionPool(host='www.cnjdz.net', port=80): Read timed out. (read timeout=10)
# HTTPConnectionPool(host='pic.taocz.com', port=80): Max retries exceeded with url: /imgupload/baihuo/jiaju/20111115/303724-3.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f37376a0>, 'Connection to pic.taocz.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.zerbuy.com', port=80): Max retries exceeded with url: /images/201708/goods_img/387_P_1503975407724.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f371e4e0>, 'Connection to www.zerbuy.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='g.search.alicdn.com', port=80): Max retries exceeded with url: /i4/i1/TB1UFyRNpXXXXcyaXXXXXXXXXXX_!!0-item_pic.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f37288d0>, 'Connection to g.search.alicdn.com timed out. (connect timeout=10)'))
# Finished 1000 out of 194,828
# HTTPConnectionPool(host='zerbuy.com', port=80): Max retries exceeded with url: /images/201708/goods_img/383_P_1503972132005.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3fb1828>, 'Connection to zerbuy.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='pic.taocz.com', port=80): Max retries exceeded with url: /imgupload/baihuo/jiaju/20111115/303723-1.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3728f60>, 'Connection to pic.taocz.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='ggl.dalmt.com', port=80): Max retries exceeded with url: /statics/uploads/shopimg/20160321/76110541548298.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3739400>, 'Connection to ggl.dalmt.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.26zh.cn', port=80): Read timed out. (read timeout=10)
# HTTPConnectionPool(host='g-search4.alicdn.com', port=80): Max retries exceeded with url: /bao/uploaded/g-search2.alicdn.com/bao/uploaded/i3/11846030023635779/T1.ti3FghbXXXXXXXX_%21%212-item_pic.png (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3737358>, 'Connection to g-search4.alicdn.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.darchin.com', port=80): Max retries exceeded with url: /uploadfile/201511/20151103095703635821414236319403.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f370c588>, 'Connection to www.darchin.com timed out. (connect timeout=10)'))
# HTTPSConnectionPool(host='img12.360buyimg.com', port=443): Max retries exceeded with url: /imgzone/jfs/t4057/26/255299553/268308/155716c5/584531a6N1d98baf7.jpg (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
# HTTPConnectionPool(host='www.zerbuy.com', port=80): Max retries exceeded with url: /images/201708/goods_img/387_P_1503975408221.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f371e400>, 'Connection to www.zerbuy.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.zerbuy.com', port=80): Max retries exceeded with url: /images/201708/goods_img/387_P_1503975408093.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3728898>, 'Connection to www.zerbuy.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.eciyu.com', port=80): Max retries exceeded with url: /images/upload/Image/%E9%94%85%E5%85%B7/2l%E8%90%9D%E5%8D%9C%E5%9B%BE%E6%A1%88%E9%99%B6%E7%93%B7%E5%BD%A9%E8%89%B2%E5%85%BB%E7%94%9F%E7%A0%82%E9%94%85/%E4%B8%BB%E5%9B%BE/QQ%E5%9B%BE%E7%89%8720161221133805.png (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3fa8ba8>, 'Connection to www.eciyu.com timed out. (connect timeout=10)'))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# HTTPConnectionPool(host='www.zhuangshangyin.com', port=80): Max retries exceeded with url: /UploadFile/20150811/productImg/033d2435-ecb5-45fc-8374-9a1cf8a6ba61.jpgc600X600.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3fb1898>, 'Connection to www.zhuangshangyin.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.wanjushe.com', port=80): Read timed out. (read timeout=10)
# Finished 2000 out of 194,828
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# HTTPConnectionPool(host='img.wezhan.cn', port=80): Read timed out. (read timeout=10)
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# HTTPConnectionPool(host='www.zhuangshangyin.com', port=80): Max retries exceeded with url: /UploadFile/20150522/productImg/fe559d6a-ec8d-41d6-8674-6cdd3ea48c80.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3737a20>, 'Connection to www.zhuangshangyin.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='img03.taobaocdn.com', port=80): Max retries exceeded with url: /bao/uploaded/i3/T1WafJFKxaXXXXXXXX_!!0-item_pic.jpg_350x350.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3737f98>, 'Connection to img03.taobaocdn.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='img03.taobaocdn.com', port=80): Max retries exceeded with url: /imgextra/i3/472449820/TB2E9v.aXXXXXcpXXXXXXXXXXXX_!!472449820.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f370c978>, 'Connection to img03.taobaocdn.com timed out. (connect timeout=10)'))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# HTTPConnectionPool(host='img03.taobaocdn.com', port=80): Max retries exceeded with url: /bao/uploaded/i3/12129021156437680/T1uWx0XAlfXXXXXXXX_!!0-item_pic.jpg_350x350.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3737a90>, 'Connection to img03.taobaocdn.com timed out. (connect timeout=10)'))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# HTTPConnectionPool(host='www.zhuangshangyin.com', port=80): Max retries exceeded with url: /UploadFile/productImg/cd325e4b-4eaf-42a3-ba55-2d0e3b6b52b1.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f371e048>, 'Connection to www.zhuangshangyin.com timed out. (connect timeout=10)'))
# HTTPSConnectionPool(host='img1.momoshop.com.tw', port=443): Read timed out. (read timeout=10)
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# Finished 3000 out of 194,828
# ("Connection broken: ConnectionResetError(104, 'Connection reset by peer')", ConnectionResetError(104, 'Connection reset by peer'))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# HTTPConnectionPool(host='www.zhuangshangyin.com', port=80): Max retries exceeded with url: /UploadFile/productImg/81570e55-2df7-407c-8572-4a7087676b92.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f370c4e0>, 'Connection to www.zhuangshangyin.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='pic.shejiben.com', port=80): Max retries exceeded with url: /mall/2013/09/30/20130930000414-c553dad7_m.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3739ac8>, 'Connection to pic.shejiben.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.best73.com', port=80): Read timed out. (read timeout=10)
# HTTPConnectionPool(host='pic.shejiben.com', port=80): Max retries exceeded with url: /mall/2013/09/26/20130926021846-91a40124_m.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f372fc88>, 'Connection to pic.shejiben.com timed out. (connect timeout=10)'))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# HTTPConnectionPool(host='m.cfskys.com', port=80): Max retries exceeded with url: /images/T1akDYXglhXXcWxwzb_124143.jpg_360x360.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3728e80>, 'Connection to m.cfskys.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.museshow.com.cn', port=80): Max retries exceeded with url: /images/TB1gaGCGpXXXXb3aXXXXXXXXXXX_%21%210-item_pic.jpg_350x350.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f371ebe0>, 'Connection to www.museshow.com.cn timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.hbpygt.com', port=80): Max retries exceeded with url: /images/T1qBCcFsBdXXXXXXXX_%21%210-item_pic.jpg_310x310.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f371e940>, 'Connection to www.hbpygt.com timed out. (connect timeout=10)'))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# HTTPConnectionPool(host='www.best73.com', port=80): Read timed out. (read timeout=10)
# HTTPConnectionPool(host='img.china.alibaba.com', port=80): Max retries exceeded with url: /img/ibank/2016/094/008/3559800490_2117351854.310x310.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3737978>, 'Connection to img.china.alibaba.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.zhuangshangyin.com', port=80): Max retries exceeded with url: /UploadFile/20150910/productImg/8802757f-4e4f-4975-88af-923813e10b7a.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3fa8160>, 'Connection to www.zhuangshangyin.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.zhuangshangyin.com', port=80): Max retries exceeded with url: /UploadFile/20150813/productImg/79caf390-4d56-4ad4-968e-3d0166982516.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f37390b8>, 'Connection to www.zhuangshangyin.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='www.zhuangshangyin.com', port=80): Max retries exceeded with url: /UploadFile/20150602/productImg/32ebbe3f-a6ee-480b-ae4c-0a0d20de77fe.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3739390>, 'Connection to www.zhuangshangyin.com timed out. (connect timeout=10)'))
# HTTPSConnectionPool(host='img2.momomall.com.tw', port=443): Read timed out. (read timeout=10)
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# HTTPConnectionPool(host='imgbdb2.bendibao.com', port=80): Max retries exceeded with url: /baikebdb/20147/18/20140718223933_19867.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f38f371eb70>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# HTTPConnectionPool(host='648.s21i-1.faidns.com', port=80): Read timed out. (read timeout=10)
# HTTPConnectionPool(host='www.viewcn.com', port=80): Max retries exceeded with url: /hxjk/wawj/images/2013/08/14/1062133.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f370c8d0>, 'Connection to www.viewcn.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='imgs.bzw315.com', port=80): Read timed out.
# Finished 4000 out of 194,828
# ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
# HTTPConnectionPool(host='www.viewcn.com', port=80): Max retries exceeded with url: /hxjk/wawj/images/2013/08/14/1062136.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f371ecf8>, 'Connection to www.viewcn.com timed out. (connect timeout=10)'))
# Exceeded 30 redirects.
# HTTPConnectionPool(host='imgbdb2.bendibao.com', port=80): Max retries exceeded with url: /bl/400_0_http://imgbdb2.bendibao.com/baikebdb/20147/18/20140718223933_19867.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f38f371e320>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# HTTPConnectionPool(host='www.zhuangshangyin.com', port=80): Max retries exceeded with url: /UploadFile/20150910/productImg/b772009d-ac7e-4809-85b3-29b3240b8449.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f372f780>, 'Connection to www.zhuangshangyin.com timed out. (connect timeout=10)'))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# HTTPSConnectionPool(host='cbu01.alicdn.com', port=443): Max retries exceeded with url: /img/ibank/2015/663/850/2115058366_2088788040.310x310.jpg (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f38f3737438>, 'Connection to cbu01.alicdn.com timed out. (connect timeout=10)'))
# HTTPSConnectionPool(host='cbu01.alicdn.com', port=443): Max retries exceeded with url: /img/ibank/2016/636/090/3369090636_90591223.310x310.jpg (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f38f371e240>, 'Connection to cbu01.alicdn.com timed out. (connect timeout=10)'))
# HTTPConnectionPool(host='img1n.soufunimg.com', port=80): Read timed out. (read timeout=10)
# HTTPConnectionPool(host='127.0.0.1', port=80): Max retries exceeded with url: /images/TB1ttv4HpXXXXaeaXXXXXXXXXXX_!!0-item_pic.jpg_310x310.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f38f3728e80>: Failed to establish a new connection: [Errno 111] Connection refused',))
# HTTPConnectionPool(host='zhuoziyizi.sofa520.net', port=80): Max retries exceeded with url: /uploads/allimg/130512/1-130512120209-52.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3737908>, 'Connection to zhuoziyizi.sofa520.net timed out. (connect timeout=10)'))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# Finished 5000 out of 194,828
# HTTPConnectionPool(host='www.zhuangshangyin.com', port=80): Max retries exceeded with url: /UploadFile/20151102/productImg/92a995f0-08b8-4256-aabd-dae22b7f03a9.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f38f3737978>, 'Connection to www.zhuangshangyin.com timed out. (connect timeout=10)'))
# ('Connection aborted.', OSError("(104, 'ECONNRESET')",))
# HTTPConnectionPool(host='static.kouclo.com', port=80): Read timed out. (read timeout=10)
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     440             try:
# --> 441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1715         result = _lib.SSL_do_handshake(self._ssl)
# -> 1716         self._raise_ssl_error(self._ssl, result)
#    1717
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1430         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1431             raise WantReadError()
#    1432         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0b02f460692d> in <module>()
#       3         print("Finished {} out of 194,828".format(img['image_id']))
#       4     try:
# ----> 5         r = requests.get(img['url'][0],timeout=10)
#       6         folder_path = 'train_data/'
#       7         with open(folder_path+str(img['image_id'])+'.jpg','wb') as f:
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     848         # Force connect early to allow us to validate the connection.
#     849         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 850             conn.connect()
#     851
#     852         if not conn.is_verified:
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/urllib3/connection.py in connect(self)
#     324             ca_cert_dir=self.ca_cert_dir,
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#     328         if self.assert_fingerprint:
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     327         context.load_cert_chain(certfile, keyfile)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#     331     warnings.warn(
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     441                 cnx.do_handshake()
#     442             except OpenSSL.SSL.WantReadError:
# --> 443                 rd = util.wait_for_read(sock, sock.gettimeout())
#     444                 if not rd:
#     445                     raise timeout('select timed out')
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/urllib3/util/wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/urllib3/util/wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/urllib3/util/selectors.py in select(self, timeout)
#     436             fd_events = _syscall_wrapper(self._epoll.poll, True,
#     437                                          timeout=timeout,
# --> 438                                          maxevents=max_events)
#     439             for fd, event_mask in fd_events:
#     440                 events = 0
#
# ~/miniconda3/envs/nlp/lib/python3.5/site-packages/urllib3/util/selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# KeyboardInterrupt:
